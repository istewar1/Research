# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from sklearn.decomposition import TruncatedSVD

# %%
inPath = '/Users/i6o/Documents/COSC 528/Project 2/'
df = pd.read_excel(inPath+'UTK-peers.xlsx')

# %%
first_row_with_all_NaN = df.shape[0]-df[df.isnull().all(axis=1) == True].shape[0]
df = df.loc[0:first_row_with_all_NaN-1]

# %%
df = df.drop(['IPEDS#','HBC','Carm R1','Med School Res $'],axis=1)

# %%
df['Wall St. Jourl Rank'][df['Name']=='Delaware']=137
df['Wall St. Jourl Rank'][df['Name']=='Colorado State']=353
df['Wall St. Jourl Rank'][df['Name']=='Arizona State']=131
df['Wall St. Jourl Rank'][df['Name']=='Georgia Tech']=51
df['Wall St. Jourl Rank'][df['Name']=='UC-Irvine']=153
df['Wall St. Jourl Rank'][df['Name']=='UC-San Diego']=49
df['Wall St. Jourl Rank'][df['Name']=='Connecticut']=110
df['Wall St. Jourl Rank'][df['Name']==' Iowa']=164
df['Wall St. Jourl Rank'][df['Name']=='Buffalo']=130
df['Wall St. Jourl Rank'][df['Name']=='Utah']=311
df['Wall St. Jourl Rank'][df['Name']=='UC-Riverside']=368
df['Wall St. Jourl Rank'][df['Name']=='Arizona']=162

# %%
df['2014 Med School'][df['2014 Med School']!='x']=0
df['2014 Med School'][df['2014 Med School']=='x']=1
df['Vet School'][df['Vet School']!='x']=0
df['Vet School'][df['Vet School']=='x']=1
df['Med School Res $'][df['Med School Res $']=='-']=0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-d0d379563898> in <module>()
#       3 df['Vet School'][df['Vet School']!='x']=0
#       4 df['Vet School'][df['Vet School']=='x']=1
# ----> 5 df['Med School Res $'][df['Med School Res $']=='-']=0
#
# /Users/i6o/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /Users/i6o/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /Users/i6o/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /Users/i6o/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/i6o/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Med School Res $'

# %%
df.isnull().any()
# Out:
# Name                                          False
# % Blk Total Students                          False
# % Hisp Total Students                         False
# 2017 US News top 65                           False
# 2014 Med School                               False
# Vet School                                    False
# Total Enroll                                  False
# % Grad Enroll                                 False
# Six-year graduation rate                      False
# ACT/ SAT Avg                                  False
# Fresh Admit Rate                              False
# % Freshmen Retention                          False
# % UG Pell Grants                              False
# % Bachelors                                   False
# % Doct/ Profess                               False
# Total E&G Expend                              False
# E&G / St. FTE                                 False
# State Approp Rev                              False
# Tuition/Fee Rev                               False
# % Rev from State                              False
# % Rev from Tuit/Fees                          False
# % from State / Tuition                        False
# Endowment                                      True
# Total Research Expenditures ($000)            False
# Student Faculty Ratio                         False
# Total Faculty                                 False
# ARU Faculty Awards                            False
# Wall St. Jourl Rank                            True
# ST. FTE                                       False
# Total Degrees                                 False
#                                               ...
# Total Revenue                                 False
# Enowment / St. FTE                             True
# Total Research Exp - Med School Exp ($000)    False
# AG Research ($000)                             True
# Total Tenure /Tenure-Track Facutly            False
# Facutly FTE                                   False
# % UG with Loans                               False
# % UG Age 25 +                                 False
# % Total Age 25 +                              False
# % Full-Time                                   False
# Faculty Academy Memb                          False
# UG Total Enroll                               False
# GR Total Enroll                               False
# Full-time Students                            False
# Part-time Students                            False
# UG Enroll Age 25 +                            False
# GR Enroll Age 25 +                            False
# Bach Degrees                                  False
# Masters Degrees                               False
# Doctoral Degrees                              False
# Profess Degrees                               False
# ACT/ SAT 25%                                  False
# ACT/ SAT 75%                                  False
# (State/ Tuit)/ St. FTE                        False
# Academic Support Expenditures                 False
# Student Services Expenditures                 False
# Endowment Figure                              False
# Endowment per Student FTE                     False
# Total Faculty.1                               False
# Total Tenure /Tenure-Track Facutly.1          False
# Length: 61, dtype: bool
